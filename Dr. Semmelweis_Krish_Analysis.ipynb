# %% [markdown]
# ### I- Yearly data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 

#Read the yearly dataset
yearly_df = pd.read_csv(r"C:\Users\Administrator\Desktop\krish_course\python_course\pylec_7\yearly_deaths_by_clinic.csv")

yearly_df
# Out:
#     year  births  deaths    clinic
# 0   1841    3036     237  clinic 1
# 1   1842    3287     518  clinic 1
# 2   1843    3060     274  clinic 1
# 3   1844    3157     260  clinic 1
# 4   1845    3492     241  clinic 1
# 5   1846    4010     459  clinic 1
# 6   1841    2442      86  clinic 2
# 7   1842    2659     202  clinic 2
# 8   1843    2739     164  clinic 2
# 9   1844    2956      68  clinic 2
# 10  1845    3241      66  clinic 2
# 11  1846    3754     105  clinic 2

# %%
print(yearly_df.shape)
print("IsNULL:\n",yearly_df.isnull().sum())
print()
print(yearly_df.info())
print()
print(yearly_df.describe())
print()
print(yearly_df)
# Out:
# (12, 4)
# IsNULL:
#  year      0
# births    0
# deaths    0
# clinic    0
# dtype: int64
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    12 non-null     int64
#  1   births  12 non-null     int64
#  2   deaths  12 non-null     int64
#  3   clinic  12 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 516.0+ bytes
# None
#
#               year       births      deaths
# count    12.000000    12.000000   12.000000
# mean   1843.500000  3152.750000  223.333333
# std       1.783765   449.078476  145.383089
# min    1841.000000  2442.000000   66.000000
# 25%    1842.000000  2901.750000  100.250000
# 50%    1843.500000  3108.500000  219.500000
# 75%    1845.000000  3338.250000  263.500000
# max    1846.000000  4010.000000  518.000000
#
#     year  births  deaths    clinic
# 0   1841    3036     237  clinic 1
# 1   1842    3287     518  clinic 1
# 2   1843    3060     274  clinic 1
# 3   1844    3157     260  clinic 1
# 4   1845    3492     241  clinic 1
# 5   1846    4010     459  clinic 1
# 6   1841    2442      86  clinic 2
# 7   1842    2659     202  clinic 2
# 8   1843    2739     164  clinic 2
# 9   1844    2956      68  clinic 2
# 10  1845    3241      66  clinic 2
# 11  1846    3754     105  clinic 2

# %%
yearly_df.groupby("clinic")["deaths"].sum()
# Out:
# clinic
# clinic 1    1989
# clinic 2     691
# Name: deaths, dtype: int64

# %% [markdown]
# #### The above results shows us the number of births and deaths in 2 clinics from the year 1841 till 1846. It's obvious that the number of deaths in clinic 1 is higher than that of clinic 2.

# %%
yearly_df.groupby("clinic")["year"].count()
# Out:
# clinic
# clinic 1    6
# clinic 2    6
# Name: year, dtype: int64

# %%
yearly_df.groupby("year")["deaths"].sum()
# Out:
# year
# 1841    323
# 1842    720
# 1843    438
# 1844    328
# 1845    307
# 1846    564
# Name: deaths, dtype: int64

# %%
yearly_df.groupby("year")["births"].sum()
# Out:
# year
# 1841    5478
# 1842    5946
# 1843    5799
# 1844    6113
# 1845    6733
# 1846    7764
# Name: births, dtype: int64

# %%
yearly_df["Proportion of Deaths"]=round((yearly_df["deaths"]/yearly_df["births"])*100,2)
yearly_df
# Out:
#     year  births  deaths    clinic  Proportion of Deaths
# 0   1841    3036     237  clinic 1                  7.81
# 1   1842    3287     518  clinic 1                 15.76
# 2   1843    3060     274  clinic 1                  8.95
# 3   1844    3157     260  clinic 1                  8.24
# 4   1845    3492     241  clinic 1                  6.90
# 5   1846    4010     459  clinic 1                 11.45
# 6   1841    2442      86  clinic 2                  3.52
# 7   1842    2659     202  clinic 2                  7.60
# 8   1843    2739     164  clinic 2                  5.99
# 9   1844    2956      68  clinic 2                  2.30
# 10  1845    3241      66  clinic 2                  2.04
# 11  1846    3754     105  clinic 2                  2.80

# %%
clinic_1=yearly_df[yearly_df["clinic"]=="clinic 1"]
clinic_2=yearly_df[yearly_df["clinic"]=="clinic 2"]
print("Clinic 1 data")
print(clinic_1)
print("Clinic 2 data")
print(clinic_2)
# Out:
# Clinic 1 data
#    year  births  deaths    clinic  Proportion of Deaths
# 0  1841    3036     237  clinic 1                  7.81
# 1  1842    3287     518  clinic 1                 15.76
# 2  1843    3060     274  clinic 1                  8.95
# 3  1844    3157     260  clinic 1                  8.24
# 4  1845    3492     241  clinic 1                  6.90
# 5  1846    4010     459  clinic 1                 11.45
# Clinic 2 data
#     year  births  deaths    clinic  Proportion of Deaths
# 6   1841    2442      86  clinic 2                  3.52
# 7   1842    2659     202  clinic 2                  7.60
# 8   1843    2739     164  clinic 2                  5.99
# 9   1844    2956      68  clinic 2                  2.30
# 10  1845    3241      66  clinic 2                  2.04
# 11  1846    3754     105  clinic 2                  2.80

# %%
#Visualize the Number of deaths every year in Both clinic
fig,ax = plt.subplots(figsize = (12,7))

plt.bar(yearly_df.year,yearly_df.deaths,width=0.6,color="grey")
plt.title("Overview: Number of Deaths per Year", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Deaths", fontsize=14)
plt.show()

# %%
#Visualize the Number of deaths every year in clinic 1
fig,ax = plt.subplots(figsize = (10,4))
plt.bar(clinic_1.year, clinic_1.deaths, width= 0.6, color= "red")
plt.title("Clinic 1: Number of Deaths per Year", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Deaths", fontsize=14)
plt.show()

# %%
#Visualize the Number of deaths every year in clinic 2
fig,ax = plt.subplots(figsize = (10,4))
plt.bar(clinic_2.year, clinic_2.deaths, width= 0.6, color= "green")
plt.title("Clinic 2: Number of Deaths per Year", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Number of Deaths", fontsize=14)
plt.show()

# %% [markdown]
# #### It seems that 1842 was a pretty hectic year in both clinic 1 & 2 where the numbers of deaths were 518 and 202 respectively

# %%
#Visualize the Number of deaths every year in Both clinic
fig,ax = plt.subplots(figsize = (10,4))

plt.bar(yearly_df.year,yearly_df["Proportion of Deaths"],width=0.6,color="red")
plt.title("Overview: Proportion of Deaths per Year", fontsize=16)
plt.xlabel("Year", fontsize=14)
plt.ylabel("Proportion of Deaths", fontsize=14)
plt.show()

# %% [markdown]
# #### Plot the proportion of deaths in clinic 1 and 2

# %%
ax=clinic_1.plot(x="year",y="Proportion of Deaths",label="clinic_1", color="red")
clinic_2.plot(x= "year", y= "Proportion of Deaths", label= "clinic_2", ax=ax, ylabel= "Proportion of Deaths", color="green")
# Out:
# <Axes: xlabel='year', ylabel='Proportion of Deaths'>

# %% [markdown]
# #### By looking further into why this happened, Dr Semmelweis realized that many medical students worked at clinic 1 who also as a part of their study, spend a lot of time in the autopsy room. So, he realized that dealing with corpses spread bacteria that would be transferred to the women giving birth, infecting them with the deadly childbed fever, which was the main reason for the high mortality rates.

# %% [markdown]
# ### II- Monthly data

# %%
# Read the monthly dataset
monthly_df = pd.read_csv(r"C:\Users\Administrator\Desktop\krish_course\python_course\pylec_7\monthly_deaths.csv")
print(monthly_df)
monthly_df["Proportion of Deaths"]=round(monthly_df['deaths']/monthly_df['births']*100,2)
print(monthly_df)
# Out:
#           date  births  deaths
# 0   1841-01-01     254      37
# 1   1841-02-01     239      18
# 2   1841-03-01     277      12
# 3   1841-04-01     255       4
# 4   1841-05-01     255       2
# ..         ...     ...     ...
# 93  1848-11-01     310       9
# 94  1848-12-01     373       5
# 95  1849-01-01     403       9
# 96  1849-02-01     389      12
# 97  1849-03-01     406      20
#
# [98 rows x 3 columns]
#           date  births  deaths  Proportion of Deaths
# 0   1841-01-01     254      37                 14.57
# 1   1841-02-01     239      18                  7.53
# 2   1841-03-01     277      12                  4.33
# 3   1841-04-01     255       4                  1.57
# 4   1841-05-01     255       2                  0.78
# ..         ...     ...     ...                   ...
# 93  1848-11-01     310       9                  2.90
# 94  1848-12-01     373       5                  1.34
# 95  1849-01-01     403       9                  2.23
# 96  1849-02-01     389      12                  3.08
# 97  1849-03-01     406      20                  4.93
#
# [98 rows x 4 columns]

# %%
print(monthly_df.shape)
# Out:
# (98, 4)

# %%
print(monthly_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  98 non-null     object
#  1   births                98 non-null     int64
#  2   deaths                98 non-null     int64
#  3   Proportion of Deaths  98 non-null     float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.2+ KB
# None

# %% [markdown]
# #### Dr Semmelweis ordered the doctors to wash their hands and made it obligatory in the summer of 1847 to see if that will affect the number of deaths, and since we have the monthly data now, we can trace the number of deaths before and after the handwashing started.

# %%
#Change the data type of "date" column from string to datatime
monthly_df['date'] =  pd.to_datetime(monthly_df['date'])
monthly_df.dtypes
# Out:
# date                    datetime64[ns]
# births                           int64
# deaths                           int64
# Proportion of Deaths           float64
# dtype: object

# %%
# Label the date at which handwashing started to "start_handwashing"
start_handwashing = pd.to_datetime('1847-06-01')

# Split monthly into before and after handwashing_start
before_washing = monthly_df[monthly_df["date"] < start_handwashing]
after_washing = monthly_df[monthly_df["date"] >= start_handwashing]
print("before_washing:\n",before_washing)
print("after_washing:\n",after_washing)
# Out:
# before_washing:
#           date  births  deaths  Proportion of Deaths
# 0  1841-01-01     254      37                 14.57
# 1  1841-02-01     239      18                  7.53
# 2  1841-03-01     277      12                  4.33
# 3  1841-04-01     255       4                  1.57
# 4  1841-05-01     255       2                  0.78
# ..        ...     ...     ...                   ...
# 71 1847-01-01     311      10                  3.22
# 72 1847-02-01     312       6                  1.92
# 73 1847-03-01     305      11                  3.61
# 74 1847-04-01     312      57                 18.27
# 75 1847-05-01     294      36                 12.24
#
# [76 rows x 4 columns]
# after_washing:
#           date  births  deaths  Proportion of Deaths
# 76 1847-06-01     268       6                  2.24
# 77 1847-07-01     250       3                  1.20
# 78 1847-08-01     264       5                  1.89
# 79 1847-09-01     262      12                  4.58
# 80 1847-10-01     278      11                  3.96
# 81 1847-11-01     246      11                  4.47
# 82 1847-12-01     273       8                  2.93
# 83 1848-01-01     283      10                  3.53
# 84 1848-02-01     291       2                  0.69
# 85 1848-03-01     276       0                  0.00
# 86 1848-04-01     305       2                  0.66
# 87 1848-05-01     313       3                  0.96
# 88 1848-06-01     264       3                  1.14
# 89 1848-07-01     269       1                  0.37
# 90 1848-08-01     261       0                  0.00
# 91 1848-09-01     312       3                  0.96
# 92 1848-10-01     299       7                  2.34
# 93 1848-11-01     310       9                  2.90
# 94 1848-12-01     373       5                  1.34
# 95 1849-01-01     403       9                  2.23
# 96 1849-02-01     389      12                  3.08
# 97 1849-03-01     406      20                  4.93

# %% [markdown]
# ### Before Handwashing

# %%
fig,ax = plt.subplots(figsize = (10,4))
x= before_washing["date"]
y= before_washing["Proportion of Deaths"]
plt.plot(x, y, color= "orange")
plt.title("Before Handwashing", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("Proportion of Deaths", fontsize=14)
# Out:
# Text(0, 0.5, 'Proportion of Deaths')

# %% [markdown]
# ### After Handwashing

# %%
fig,ax = plt.subplots(figsize = (10,4))
x= after_washing["date"]
y= after_washing["Proportion of Deaths"]
plt.plot(x, y, color= "blue")
plt.title("Before Handwashing", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("Proportion of Deaths", fontsize=14)
# Out:
# Text(0, 0.5, 'Proportion of Deaths')

# %% [markdown]
# #### To see the difference clearly, let's combine the 2 plots in one chart.

# %%
ax= before_washing.plot(x= "date", y= "Proportion of Deaths", label= "Before Handwashing", color="red")
after_washing.plot(x= "date", y= "Proportion of Deaths", label= "After Handwashing", ax=ax, ylabel= "Proportion deaths", color="blue")
# Out:
# <Axes: xlabel='date', ylabel='Proportion deaths'>

# %% [markdown]
# #### The difference is pretty clear! the proportion of deaths dramatically decreased after handwashing was made obligatory.

# %% [markdown]
# #### Let's calculate exactly how much did handwashing decreased the proportion of deaths on average.

# %%
before_proportion = before_washing["Proportion of Deaths"]
after_proportion = after_washing["Proportion of Deaths"]
before_proportion.mean()
# Out:
# np.float64(10.504736842105261)

# %%
after_proportion.mean()
# Out:
# np.float64(2.109090909090909)

# %%
# Calculate the difference between both proportions
mean_diff = after_proportion.mean() - before_proportion.mean()
print("difference between both proportions",round(mean_diff,1))
# Out:
# difference between both proportions -8.4

# %% [markdown]
# #### The minus sign indicate that there is a decrease. So handwashing decreased the proportion of deaths from 10% to 2% i.e, by approximately 8%.
